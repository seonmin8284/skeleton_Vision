# %%
import json

# %%
weight = int(input('하중(kg)을 설정해주세요.'))     ## 하중 설정은 이미지별로 하는 게 아니라, 가장 처음에 기입되고 시작해야 한다고 생각했습니다.
if weight <= 10:
    weight_code = 1
elif weight <= 20:
    weight_code = 2
else:
    weight_code = 3
# Out:
# 하중(kg)을 설정해주세요.15

# %%
with open('D:\\hack\\F01Json-Final\\F01_P001_A1_W001_D2022-08-23-10-12-00_0001.json', 'r') as f:
    json_data = json.load(f)
json_data
# Out:
# {'images': [{'id': 1,
#    'file_name': 'F01_P001_A1_W001_D2022-08-23-10-12-00_0001.jpg',
#    'width': 3840,
#    'height': 2160,
#    'date_captured': '2022-08-23 10:12:00',
#    'angle': 1}],
#  'annotations': [{'id': 1,
#    'image_id': 1,
#    'category_id': 0,
#    'factory': 1,
#    'process': 1,
#    'worker': 1,
#    'posture': {'neck': '2',
#     'trunk': '1',
#     'upperarm': '0',
#     'lowerarm': '0',
#     'legs': '4'},
#    'bbox': [1680.8000000000002, 848.0, 2113.6, 1568.0],
#    'keypoints': [[2082.4, 917.6, 1],
#     [2073.6, 955.2, 1],
#     [2049.6, 916.0, 2],
#     [2040.0, 972.8000000000001, 1],
#     [2031.2, 893.6, 1],
#     [1917.6000000000001, 875.2, 1],
#     [1930.4, 1016.8000000000001, 1],
#     [1932.8000000000002, 1098.4, 1],
#     [1947.2, 1124.0, 1],
#     [1916.8000000000002, 1138.4, 1],
#     [1935.2, 1133.6000000000001, 1],
#     [2027.2, 902.4000000000001, 2],
#     [1965.6000000000001, 997.6, 2],
#     [1936.8000000000002, 1076.0, 2],
# ...

# %%
## 우선 제공된 Json 파일을 통해서 점수 계산했으며,
## JSON 파일이 아니라 어떤 방식으로든 넘겨 주시면 그 부분만 수정해도 되니까 괜찮습니다.

trunk_code = int(json_data['annotations'][0]['posture']['trunk']) + int(json_data['annotations'][0]['trunk_twist'])
arm_code = int(json_data['annotations'][0]['posture']['lowerarm']) + 1
leg_code = int(json_data['annotations'][0]['posture']['legs']) + 1

# %%
owas_code = str(trunk_code) + str(arm_code) + str(leg_code) + str(weight_code)

# %%
## 무식하게 구현해봤습니다. 사실 뒤에 있는 이진탐색이 훨씬 효율적이라고 생각하는데.. 아까워서 이 부분 지우지 못했습니다.

def get_level(owas_code):
    if owas_code[0] == '1':
        if owas_code[1] == '1':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
        elif owas_code[1] == '2':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
        elif owas_code[1] == '3':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 2
                    
                    
    elif owas_code[0] == '2':
        if owas_code[1] == '1':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
        elif owas_code[1] == '2':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
        elif owas_code[1] == '3':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
                    
                    
    elif owas_code[0] == '3':
        if owas_code[1] == '1':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
        elif owas_code[1] == '2':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 2
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_codes_code[3] == '3':
                    level = 1
        elif owas_code[1] == '3':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 1
                elif owas_code[3] == '2':
                    level = 1
                elif owas_code[3] == '3':
                    level = 1
                    
                
    elif owas_code[0] == '4':
        if owas_code[1] == '1':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 2
                elif owas_code[3] == '3':
                    level = 3
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
        elif owas_code[1] == '2':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
        elif owas_code[1] == '3':
            if owas_code[2] == '1':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '2':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '3':
                if owas_code[3] == '1':
                    level = 3
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '4':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '5':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '6':
                if owas_code[3] == '1':
                    level = 4
                elif owas_code[3] == '2':
                    level = 4
                elif owas_code[3] == '3':
                    level = 4
            elif owas_code[2] == '7':
                if owas_code[3] == '1':
                    level = 2
                elif owas_code[3] == '2':
                    level = 3
                elif owas_code[3] == '3':
                    level = 4
                    
    return level

# %%
get_level(owas_code)
# Out:
# 2

# %%
## 다시 생각해보니까 이진탐색이 더 빠를 것 같아서 이진탐색으로 해봤습니다.
## 전체 OWAS CODE는 4*3*7*3 으로 252개 인데, 이진탐색으로 진행하면 2^8 = 256이기 때문에 8번만에 찾을 수 있습니다.

from bisect import bisect_left

dic = {
    1111: 1, 1311: 1, 2211: 2, 3111: 1, 3311: 2, 4211: 3,
    1112: 1, 1312: 1, 2212: 2, 3112: 1, 3312: 2, 4212: 3,
    1113: 1, 1313: 1, 2213: 3, 3113: 1, 3313: 3, 4213: 4,
    1121: 1, 1321: 1, 2221: 2, 3121: 1, 3321: 1, 4221: 2,
    1122: 1, 1322: 1, 2222: 2, 3122: 1, 3322: 1, 4222: 3,
    1123: 1, 1323: 1, 2223: 3, 3123: 1, 3323: 1, 4223: 4,
    1131: 1, 1331: 1, 2231: 2, 3131: 1, 3331: 2, 4231: 3,
    1132: 1, 1332: 1, 2232: 3, 3132: 1, 3332: 3, 4232: 3,
    1133: 1, 1333: 1, 2233: 3, 3133: 2, 3333: 3, 4233: 4,
    1141: 2, 1341: 2, 2241: 3, 3141: 3, 3341: 4, 4241: 4,
    1142: 2, 1342: 2, 2242: 4, 3142: 3, 3342: 4, 4242: 4,
    1143: 2, 1343: 3, 2243: 4, 3143: 3, 3343: 4, 4243: 4,
    1151: 2, 1351: 2, 2251: 3, 3151: 4, 3351: 4, 4251: 4,
    1152: 2, 1352: 2, 2252: 4, 3152: 4, 3352: 4, 4252: 4,
    1153: 2, 1353: 3, 2253: 4, 3153: 4, 3353: 4, 4253: 4,
    1161: 1, 1361: 1, 2261: 3, 3161: 1, 3361: 4, 4261: 4,
